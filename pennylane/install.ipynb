# %%
# Install PennyLane
# !uv add pennylane
# !uv sync
# Out:
# Resolved 191 packages in 496ms
# ⠙ Preparing packages... (0/3)                                                   ⠋ Preparing packages... (0/0)
# ⠙ Preparing packages... (0/3)--------------     0 B/11.23 KiB
# ⠙ Preparing packages... (0/3)---------- 11.23 KiB/11.23 KiB
# ⠙ Preparing packages... (0/3)---------- 11.23 KiB/11.23 KiB
# cachetools           ------------------------------ 11.23 KiB/11.23 KiB
# ⠙ Preparing packages... (0/3)--------------     0 B/5.03 MiB
# cachetools           ------------------------------ 11.23 KiB/11.23 KiB
# ⠙ Preparing packages... (0/3)--------------     0 B/5.03 MiB
# ⠙ Preparing packages... (0/3)--------------     0 B/5.03 MiB
# ⠙ Preparing packages... (0/3)-------------- 8.74 KiB/5.03 MiB
# ⠙ Preparing packages... (0/3)-------------- 24.74 KiB/5.03 MiB
# ⠙ Preparing packages... (0/3)-------------- 40.74 KiB/5.03 MiB
# ⠙ Preparing packages... (0/3)-------------- 56.74 KiB/5.03 MiB
# ⠙ Preparing packages... (0/3)-------------- 72.74 KiB/5.03 MiB
# ...
