# %%
# Install Qiskit and dependencies
# !uv add qiskit qiskit-ibm-runtime "qiskit[visualization]" qiskit-aer

# Install LaTeX encoding for quantum circuit visualization
# !uv add pylatexenc
# !uv sync
# Out:
# Resolved 177 packages in 496ms
# Installed 18 packages in 123ms                                   ░░░░░░░░░░░░░░░░░░░░ [0/0] Installing wheels...
#  + annotated-types==0.7.0
#  + dill==0.4.0
#  + ibm-cloud-sdk-core==3.24.2
#  + ibm-platform-services==0.71.0
#  + pydantic==2.12.4
#  + pydantic-core==2.41.5
#  + pydot==4.0.1
#  + pylatexenc==2.10
#  + pyspnego==0.12.0
#  + qiskit==2.2.3
#  + qiskit-aer==0.17.2
#  + qiskit-ibm-runtime==0.43.1
#  + requests-ntlm==1.3.0
#  + rustworkx==0.17.1
#  + scipy==1.16.3
#  + seaborn==0.13.2
#  + stevedore==5.5.0
#  + typing-inspection==0.4.2
# ⠙ yt-dlp==2025.11.12                                                            Resolved 177 packages in 37ms
# Audited 168 packages in 5ms
# Resolved 177 packages in 4ms
# Audited 168 packages in 3ms
